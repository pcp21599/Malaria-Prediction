# %%
import pandas as pd

# %%
data=pd.read_csv("Data.csv")
frame=pd.DataFrame(data)
Total = frame["Total_Case"]
Outbreak=[]

# %%
for x in Total:
    if x>200:
        Outbreak.append("Yes")
    else:
        Outbreak.append("No")

# %%
Outbreak = pd.DataFrame(Outbreak)

# %%
frame["Outbreak"] =Outbreak

# %%
frame.to_csv("Final Data.csv",index= False)
Outbreak
# Out:
#        0
# 0    Yes
# 1    Yes
# 2    Yes
# 3     No
# 4     No
# 5     No
# 6     No
# 7    Yes
# 8    Yes
# 9    Yes
# 10   Yes
# 11   Yes
# 12   Yes
# 13   Yes
# 14   Yes
# 15    No
# 16    No
# 17    No
# 18    No
# 19   Yes
# 20   Yes
# 21   Yes
# 22   Yes
# 23   Yes
# 24   Yes
# 25   Yes
# 26   Yes
# 27    No
# 28    No
# 29    No
# ..   ...
# 90    No
# 91    No
# 92   Yes
# 93   Yes
# 94   Yes
# 95   Yes
# 96   Yes
# 97   Yes
# 98   Yes
# 99    No
# 100   No
# 101   No
# 102   No
# 103   No
# 104  Yes
# 105  Yes
# 106  Yes
# 107  Yes
# 108   No
# 109   No
# 110   No
# 111   No
# 112   No
# 113   No
# 114   No
# 115   No
# 116   No
# 117   No
# 118   No
# 119   No
#
# [120 rows x 1 columns]

# %%
a=[]
for c in Outbreak:

    if c=="Yes":
        a.append("1")
    else:
        a.append("0")
